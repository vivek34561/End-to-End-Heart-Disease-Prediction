# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'C:\Users\vivek gupta\Desktop\Heart_disease_prediction\notebook\data\raw.csv')

# %%
df.head()
# Out:
#     Age  Gender  Blood Pressure  Cholesterol Level Exercise Habits Smoking  \
# 0  56.0    Male           153.0              155.0            High     Yes
# 1  69.0  Female           146.0              286.0            High      No
# 2  46.0    Male           126.0              216.0             Low      No
# 3  32.0  Female           122.0              293.0            High     Yes
# 4  60.0    Male           166.0              242.0             Low     Yes
#
#   Family Heart Disease Diabetes        BMI High Blood Pressure  ...  \
# 0                  Yes       No  24.991591                 Yes  ...
# 1                  Yes      Yes  25.221799                  No  ...
# 2                   No       No  29.855447                  No  ...
# 3                  Yes       No  24.130477                 Yes  ...
# 4                  Yes      Yes  20.486289                 Yes  ...
#
#   High LDL Cholesterol Alcohol Consumption Stress Level Sleep Hours  \
# 0                   No                High       Medium    7.633228
# 1                   No              Medium         High    8.744034
# 2                  Yes                 Low          Low    4.440440
# 3                  Yes                 Low         High    5.249405
# 4                   No                 Low         High    7.030971
#
#    Sugar Consumption Triglyceride Level  Fasting Blood Sugar  CRP Level  \
# 0             Medium              342.0                  NaN  12.969246
# 1             Medium              133.0                157.0   9.355389
# 2                Low              393.0                 92.0  12.709873
# 3               High              293.0                 94.0  12.509046
# 4               High              263.0                154.0  10.381259
#
#    Homocysteine Level  Heart Disease Status
# 0           12.387250                    No
# 1           19.298875                    No
# 2           11.230926                    No
# 3            5.961958                    No
# 4            8.153887                    No
#
# [5 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Blood Pressure', 'Cholesterol Level',
#        'Exercise Habits', 'Smoking', 'Family Heart Disease', 'Diabetes', 'BMI',
#        'High Blood Pressure', 'Low HDL Cholesterol', 'High LDL Cholesterol',
#        'Alcohol Consumption', 'Stress Level', 'Sleep Hours',
#        'Sugar Consumption', 'Triglyceride Level', 'Fasting Blood Sugar',
#        'CRP Level', 'Homocysteine Level', 'Heart Disease Status'],
#       dtype='object')

# %%
df.shape
# Out:
# (9803, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9803 entries, 0 to 9802
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Age                   9803 non-null   float64
#  1   Gender                9784 non-null   object
#  2   Blood Pressure        9803 non-null   float64
#  3   Cholesterol Level     9803 non-null   float64
#  4   Exercise Habits       9778 non-null   object
#  5   Smoking               9778 non-null   object
#  6   Family Heart Disease  9782 non-null   object
#  7   Diabetes              9773 non-null   object
#  8   BMI                   9803 non-null   float64
#  9   High Blood Pressure   9777 non-null   object
#  10  Low HDL Cholesterol   9778 non-null   object
#  11  High LDL Cholesterol  9777 non-null   object
#  12  Alcohol Consumption   7268 non-null   object
#  13  Stress Level          9781 non-null   object
#  14  Sleep Hours           9803 non-null   float64
#  15  Sugar Consumption     9773 non-null   object
#  16  Triglyceride Level    9803 non-null   float64
#  17  Fasting Blood Sugar   9781 non-null   float64
#  18  CRP Level             9803 non-null   float64
#  19  Homocysteine Level    9803 non-null   float64
#  20  Heart Disease Status  9803 non-null   object
# dtypes: float64(9), object(12)
# memory usage: 1.6+ MB

# %%
df.isnull().sum()
# Out:
# Age                        0
# Gender                    19
# Blood Pressure             0
# Cholesterol Level          0
# Exercise Habits           25
# Smoking                   25
# Family Heart Disease      21
# Diabetes                  30
# BMI                        0
# High Blood Pressure       26
# Low HDL Cholesterol       25
# High LDL Cholesterol      26
# Alcohol Consumption     2535
# Stress Level              22
# Sleep Hours                0
# Sugar Consumption         30
# Triglyceride Level         0
# Fasting Blood Sugar       22
# CRP Level                  0
# Homocysteine Level         0
# Heart Disease Status       0
# dtype: int64

# %%
df['Alcohol Consumption'].unique()
# Out:
# array(['High', 'Medium', 'Low', nan], dtype=object)

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female', nan], dtype=object)

# %%
df[df['Gender'].isnull()]
# Out:
#        Age Gender  Blood Pressure  Cholesterol Level Exercise Habits Smoking  \
# 406   50.0    NaN           147.0              264.0             Low     Yes
# 1507  43.0    NaN           152.0              187.0             Low      No
# 1723  24.0    NaN           150.0              289.0          Medium      No
# 1908  54.0    NaN           176.0              171.0             Low     Yes
# 2007  62.0    NaN           134.0              195.0          Medium     Yes
# 2352  20.0    NaN           135.0              155.0            High      No
# 2862  18.0    NaN           170.0              204.0            High     Yes
# 3158  37.0    NaN           135.0              207.0          Medium     Yes
# 3186  33.0    NaN           142.0              240.0             Low     Yes
# 3763  47.0    NaN           157.0              216.0          Medium     Yes
# 3879  61.0    NaN           158.0              180.0             Low     Yes
# 4342  70.0    NaN           138.0              294.0             Low     Yes
# 4721  20.0    NaN           133.0              295.0            High      No
# 5494  31.0    NaN           139.0              279.0          Medium      No
# 5868  46.0    NaN           128.0              280.0          Medium      No
# 5941  18.0    NaN           138.0              213.0             Low      No
# 7005  21.0    NaN           135.0              232.0            High     Yes
# 7150  36.0    NaN           124.0              259.0          Medium      No
# 9139  24.0    NaN           153.0              191.0            High      No
#
#      Family Heart Disease Diabetes        BMI High Blood Pressure  ...  \
# 406                    No       No  20.738247                  No  ...
# 1507                  Yes       No  33.284306                 Yes  ...
# 1723                   No      Yes  37.468353                 Yes  ...
# 1908                  Yes       No  34.130846                  No  ...
# 2007                  Yes       No  20.288229                  No  ...
# 2352                   No      Yes  38.974130                 Yes  ...
# 2862                  Yes       No  33.050938                 Yes  ...
# 3158                  Yes       No  39.741540                  No  ...
# 3186                  Yes      Yes  38.093540                 Yes  ...
# 3763                  Yes      Yes  27.911349                 Yes  ...
# 3879                  Yes       No  22.856817                 Yes  ...
# 4342                   No       No  38.603827                 Yes  ...
# 4721                  Yes      Yes  36.293617                 Yes  ...
# 5494                   No      Yes  20.018047                  No  ...
# 5868                  Yes      Yes  20.637284                  No  ...
# 5941                   No       No  18.229401                 Yes  ...
# 7005                   No       No  32.301849                 Yes  ...
# 7150                   No      Yes  33.284010                 Yes  ...
# 9139                   No      Yes  22.889657                  No  ...
#
#      High LDL Cholesterol Alcohol Consumption Stress Level Sleep Hours  \
# 406                   Yes                 Low         High    8.336586
# 1507                  Yes              Medium       Medium    7.296031
# 1723                  Yes                High       Medium    9.437677
# 1908                  Yes                 NaN       Medium    6.503275
# 2007                  Yes                 NaN       Medium    5.793387
# 2352                   No              Medium       Medium    5.177439
# 2862                  Yes                High          Low    6.110008
# 3158                   No                 NaN          Low    9.508101
# 3186                  Yes                 Low         High    4.462218
# 3763                   No                 Low       Medium    9.121349
# 3879                   No              Medium          Low    9.353875
# 4342                   No                 Low         High    9.761877
# 4721                   No                 Low       Medium    6.980507
# 5494                   No                High          Low    8.754598
# 5868                   No                 NaN          Low    7.688483
# 5941                  Yes              Medium       Medium    5.028232
# 7005                  Yes                 NaN       Medium    7.090035
# 7150                   No                High       Medium    8.442871
# 9139                  Yes                 NaN          Low    5.361909
#
#       Sugar Consumption Triglyceride Level  Fasting Blood Sugar  CRP Level  \
# 406              Medium              250.0                118.0   8.867577
# 1507             Medium              301.0                156.0   9.886391
# 1723                Low              286.0                 87.0   2.558269
# 1908               High              140.0                141.0   3.246492
# 2007             Medium              130.0                135.0   4.169477
# 2352               High              328.0                100.0   7.147045
# 2862               High              264.0                156.0  10.342341
# 3158             Medium              132.0                133.0  11.894277
# 3186             Medium              296.0                101.0   2.561409
# 3763               High              175.0                 84.0  13.921607
# 3879               High              204.0                110.0  12.612396
# 4342             Medium              109.0                129.0  10.288072
# 4721             Medium              257.0                152.0   2.304016
# 5494               High              396.0                121.0   6.939385
# 5868             Medium              240.0                112.0   9.905170
# 5941             Medium              380.0                106.0  10.716954
# 7005                Low              319.0                104.0   8.380104
# 7150             Medium              387.0                135.0  14.015594
# 9139             Medium              381.0                122.0   3.490640
#
#       Homocysteine Level  Heart Disease Status
# 406            16.841735                    No
# 1507           12.976745                    No
# 1723            8.752621                    No
# 1908           14.371188                    No
# 2007           13.851085                    No
# 2352           16.562374                    No
# 2862            5.599611                    No
# 3158            8.996898                    No
# 3186            6.623389                    No
# 3763            8.362707                    No
# 3879           12.595595                    No
# 4342            7.776856                    No
# 4721           15.133149                    No
# 5494            8.911071                    No
# 5868            5.211774                    No
# 5941           14.576371                    No
# 7005            5.515841                    No
# 7150           14.485033                    No
# 9139            5.512690                   Yes
#
# [19 rows x 21 columns]

# %%
df['Exercise Habits'].unique()
# Out:
# array(['High', 'Low', 'Medium', nan], dtype=object)

# %% [markdown]
# ### Target
# 1-> handle null values
#
# remove null rows Gender , Exercise Habits , Smoking , Family Heart Disease , Diabetes
# High Blood Pressure   ,
# Low HDL Cholesterol  ,
# High LDL Cholesterol  ,
# Stress Level      ,
# Sugar Consumption   ,
# Fasting Blood Sugar  ,

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Blood Pressure', 'Cholesterol Level',
#        'Exercise Habits', 'Smoking', 'Family Heart Disease', 'Diabetes', 'BMI',
#        'High Blood Pressure', 'Low HDL Cholesterol', 'High LDL Cholesterol',
#        'Alcohol Consumption', 'Stress Level', 'Sleep Hours',
#        'Sugar Consumption', 'Triglyceride Level', 'Fasting Blood Sugar',
#        'CRP Level', 'Homocysteine Level', 'Heart Disease Status'],
#       dtype='object')

# %%
df['Heart Disease Status'].value_counts()
# Out:
# Heart Disease Status
# No     7840
# Yes    1963
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#                Age  Blood Pressure  Cholesterol Level          BMI  \
# count  9803.000000     9803.000000        9803.000000  9803.000000
# mean     49.280016      149.789962         225.414873    29.070146
# std      18.208938       17.568064          43.542435     6.305888
# min      18.000000      120.000000         150.000000    18.002837
# 25%      34.000000      134.000000         187.000000    23.652362
# 50%      49.000000      150.000000         226.000000    29.070264
# 75%      65.000000      165.000000         263.000000    34.509014
# max      80.000000      180.000000         300.000000    39.996954
#
#        Sleep Hours  Triglyceride Level  Fasting Blood Sugar    CRP Level  \
# count  9803.000000         9803.000000          9781.000000  9803.000000
# mean      6.990915          250.560747           120.124834     7.456838
# std       1.751435           87.099590            23.573417     4.343845
# min       4.000605          100.000000            80.000000     0.003647
# 25%       5.450650          176.000000            99.000000     3.650037
# 50%       7.003252          250.000000           120.000000     7.456422
# 75%       8.529969          326.000000           141.000000    11.228057
# max       9.999952          400.000000           160.000000    14.997087
#
#        Homocysteine Level
# count         9803.000000
# mean            12.446813
# std              4.321450
# min              5.000236
# 25%              8.715864
# 50%             12.399522
# 75%             16.129484
# max             19.999037

# %%
df.head()
# Out:
#     Age  Gender  Blood Pressure  Cholesterol Level Exercise Habits Smoking  \
# 0  56.0    Male           153.0              155.0            High     Yes
# 1  69.0  Female           146.0              286.0            High      No
# 2  46.0    Male           126.0              216.0             Low      No
# 3  32.0  Female           122.0              293.0            High     Yes
# 4  60.0    Male           166.0              242.0             Low     Yes
#
#   Family Heart Disease Diabetes        BMI High Blood Pressure  ...  \
# 0                  Yes       No  24.991591                 Yes  ...
# 1                  Yes      Yes  25.221799                  No  ...
# 2                   No       No  29.855447                  No  ...
# 3                  Yes       No  24.130477                 Yes  ...
# 4                  Yes      Yes  20.486289                 Yes  ...
#
#   High LDL Cholesterol Alcohol Consumption Stress Level Sleep Hours  \
# 0                   No                High       Medium    7.633228
# 1                   No              Medium         High    8.744034
# 2                  Yes                 Low          Low    4.440440
# 3                  Yes                 Low         High    5.249405
# 4                   No                 Low         High    7.030971
#
#    Sugar Consumption Triglyceride Level  Fasting Blood Sugar  CRP Level  \
# 0             Medium              342.0                  NaN  12.969246
# 1             Medium              133.0                157.0   9.355389
# 2                Low              393.0                 92.0  12.709873
# 3               High              293.0                 94.0  12.509046
# 4               High              263.0                154.0  10.381259
#
#    Homocysteine Level  Heart Disease Status
# 0           12.387250                    No
# 1           19.298875                    No
# 2           11.230926                    No
# 3            5.961958                    No
# 4            8.153887                    No
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9803 entries, 0 to 9802
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Age                   9803 non-null   float64
#  1   Gender                9784 non-null   object
#  2   Blood Pressure        9803 non-null   float64
#  3   Cholesterol Level     9803 non-null   float64
#  4   Exercise Habits       9778 non-null   object
#  5   Smoking               9778 non-null   object
#  6   Family Heart Disease  9782 non-null   object
#  7   Diabetes              9773 non-null   object
#  8   BMI                   9803 non-null   float64
#  9   High Blood Pressure   9777 non-null   object
#  10  Low HDL Cholesterol   9778 non-null   object
#  11  High LDL Cholesterol  9777 non-null   object
#  12  Alcohol Consumption   7268 non-null   object
#  13  Stress Level          9781 non-null   object
#  14  Sleep Hours           9803 non-null   float64
#  15  Sugar Consumption     9773 non-null   object
#  16  Triglyceride Level    9803 non-null   float64
#  17  Fasting Blood Sugar   9781 non-null   float64
#  18  CRP Level             9803 non-null   float64
#  19  Homocysteine Level    9803 non-null   float64
#  20  Heart Disease Status  9803 non-null   object
# dtypes: float64(9), object(12)
# memory usage: 1.6+ MB

# %%
df.isnull().sum()
# Out:
# Age                        0
# Gender                    19
# Blood Pressure             0
# Cholesterol Level          0
# Exercise Habits           25
# Smoking                   25
# Family Heart Disease      21
# Diabetes                  30
# BMI                        0
# High Blood Pressure       26
# Low HDL Cholesterol       25
# High LDL Cholesterol      26
# Alcohol Consumption     2535
# Stress Level              22
# Sleep Hours                0
# Sugar Consumption         30
# Triglyceride Level         0
# Fasting Blood Sugar       22
# CRP Level                  0
# Homocysteine Level         0
# Heart Disease Status       0
# dtype: int64

# %%
df.shape
# Out:
# (9803, 21)

# %%
# Separate categorical and numerical columns
categorical_cols = df.select_dtypes(include=['object', 'category']).columns.tolist()
numerical_cols = df.select_dtypes(include=['number']).columns.tolist()

print("Categorical Columns:", categorical_cols)
print("Numerical Columns:", numerical_cols)
# Out:
# Categorical Columns: ['Gender', 'Exercise Habits', 'Smoking', 'Family Heart Disease', 'Diabetes', 'High Blood Pressure', 'Low HDL Cholesterol', 'High LDL Cholesterol', 'Alcohol Consumption', 'Stress Level', 'Sugar Consumption', 'Heart Disease Status']
# Numerical Columns: ['Age', 'Blood Pressure', 'Cholesterol Level', 'BMI', 'Sleep Hours', 'Triglyceride Level', 'Fasting Blood Sugar', 'CRP Level', 'Homocysteine Level']

# %%
import numpy as np
import pandas as pd

# Set random seed for reproducibility
np.random.seed(42)

# Example: simulate your dataset (use your actual DataFrame instead)
# df = pd.read_csv('your_dataset.csv')

# Define categories
categories = ['High', 'Medium', 'Low']

# Identify missing values in 'Alcohol Consumption'
mask = df['Alcohol Consumption'].isna()

# Randomly assign values with equal probability
df.loc[mask, 'Alcohol Consumption'] = np.random.choice(categories, size=mask.sum(), replace=True)

# %%
# Handling missing values 
# gender -> mode
# exercise habits -> mode
# smoking -> mode
# Family Heart Disease -> mode
# diabeties -> mode
# High Blood Pressure -> mode
# Low HDL Cholesterol -> mode
# stress Level -> mode
# sugar Consumption -> mode
# fasting Blood Sugar -> mean
# Drop columns with too many missing values
threshold = 0.4  # 40%
missing_percent = df.isnull().sum() / len(df)
df = df.drop(columns=missing_percent[missing_percent > threshold].index)

# Fill categorical with mode
cat_cols = df.select_dtypes(include=['object', 'category']).columns
for col in cat_cols:
    df[col] = df[col].fillna(df[col].mode()[0])

# Fill numerical with median
num_cols = df.select_dtypes(include=['number']).columns
for col in num_cols:
    df[col] = df[col].fillna(df[col].median())

# %%
df.isnull().sum()
# Out:
# Age                     0
# Gender                  0
# Blood Pressure          0
# Cholesterol Level       0
# Exercise Habits         0
# Smoking                 0
# Family Heart Disease    0
# Diabetes                0
# BMI                     0
# High Blood Pressure     0
# Low HDL Cholesterol     0
# High LDL Cholesterol    0
# Alcohol Consumption     0
# Stress Level            0
# Sleep Hours             0
# Sugar Consumption       0
# Triglyceride Level      0
# Fasting Blood Sugar     0
# CRP Level               0
# Homocysteine Level      0
# Heart Disease Status    0
# dtype: int64

# %%
df.head()
# Out:
#     Age  Gender  Blood Pressure  Cholesterol Level Exercise Habits Smoking  \
# 0  56.0    Male           153.0              155.0            High     Yes
# 1  69.0  Female           146.0              286.0            High      No
# 2  46.0    Male           126.0              216.0             Low      No
# 3  32.0  Female           122.0              293.0            High     Yes
# 4  60.0    Male           166.0              242.0             Low     Yes
#
#   Family Heart Disease Diabetes        BMI High Blood Pressure  ...  \
# 0                  Yes       No  24.991591                 Yes  ...
# 1                  Yes      Yes  25.221799                  No  ...
# 2                   No       No  29.855447                  No  ...
# 3                  Yes       No  24.130477                 Yes  ...
# 4                  Yes      Yes  20.486289                 Yes  ...
#
#   High LDL Cholesterol Alcohol Consumption Stress Level Sleep Hours  \
# 0                   No                High       Medium    7.633228
# 1                   No              Medium         High    8.744034
# 2                  Yes                 Low          Low    4.440440
# 3                  Yes                 Low         High    5.249405
# 4                   No                 Low         High    7.030971
#
#    Sugar Consumption Triglyceride Level  Fasting Blood Sugar  CRP Level  \
# 0             Medium              342.0                120.0  12.969246
# 1             Medium              133.0                157.0   9.355389
# 2                Low              393.0                 92.0  12.709873
# 3               High              293.0                 94.0  12.509046
# 4               High              263.0                154.0  10.381259
#
#    Homocysteine Level  Heart Disease Status
# 0           12.387250                    No
# 1           19.298875                    No
# 2           11.230926                    No
# 3            5.961958                    No
# 4            8.153887                    No
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9803 entries, 0 to 9802
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Age                   9803 non-null   float64
#  1   Gender                9803 non-null   object
#  2   Blood Pressure        9803 non-null   float64
#  3   Cholesterol Level     9803 non-null   float64
#  4   Exercise Habits       9803 non-null   object
#  5   Smoking               9803 non-null   object
#  6   Family Heart Disease  9803 non-null   object
#  7   Diabetes              9803 non-null   object
#  8   BMI                   9803 non-null   float64
#  9   High Blood Pressure   9803 non-null   object
#  10  Low HDL Cholesterol   9803 non-null   object
#  11  High LDL Cholesterol  9803 non-null   object
#  12  Alcohol Consumption   9803 non-null   object
#  13  Stress Level          9803 non-null   object
#  14  Sleep Hours           9803 non-null   float64
#  15  Sugar Consumption     9803 non-null   object
#  16  Triglyceride Level    9803 non-null   float64
#  17  Fasting Blood Sugar   9803 non-null   float64
#  18  CRP Level             9803 non-null   float64
#  19  Homocysteine Level    9803 non-null   float64
#  20  Heart Disease Status  9803 non-null   object
# dtypes: float64(9), object(12)
# memory usage: 1.6+ MB

# %%
df.head()
# Out:
#     Age  Gender  Blood Pressure  Cholesterol Level Exercise Habits Smoking  \
# 0  56.0    Male           153.0              155.0            High     Yes
# 1  69.0  Female           146.0              286.0            High      No
# 2  46.0    Male           126.0              216.0             Low      No
# 3  32.0  Female           122.0              293.0            High     Yes
# 4  60.0    Male           166.0              242.0             Low     Yes
#
#   Family Heart Disease Diabetes        BMI High Blood Pressure  ...  \
# 0                  Yes       No  24.991591                 Yes  ...
# 1                  Yes      Yes  25.221799                  No  ...
# 2                   No       No  29.855447                  No  ...
# 3                  Yes       No  24.130477                 Yes  ...
# 4                  Yes      Yes  20.486289                 Yes  ...
#
#   High LDL Cholesterol Alcohol Consumption Stress Level Sleep Hours  \
# 0                   No                High       Medium    7.633228
# 1                   No              Medium         High    8.744034
# 2                  Yes                 Low          Low    4.440440
# 3                  Yes                 Low         High    5.249405
# 4                   No                 Low         High    7.030971
#
#    Sugar Consumption Triglyceride Level  Fasting Blood Sugar  CRP Level  \
# 0             Medium              342.0                120.0  12.969246
# 1             Medium              133.0                157.0   9.355389
# 2                Low              393.0                 92.0  12.709873
# 3               High              293.0                 94.0  12.509046
# 4               High              263.0                154.0  10.381259
#
#    Homocysteine Level  Heart Disease Status
# 0           12.387250                    No
# 1           19.298875                    No
# 2           11.230926                    No
# 3            5.961958                    No
# 4            8.153887                    No
#
# [5 rows x 21 columns]

# %%
# import pandas as pd

# def detect_outliers_iqr(df):
#     outlier_columns = {}
#     for col in df.select_dtypes(include=['float64', 'int64']).columns:
#         Q1 = df[col].quantile(0.25)
#         Q3 = df[col].quantile(0.75)
#         IQR = Q3 - Q1
#         lower_bound = Q1 - 1.5 * IQR
#         upper_bound = Q3 + 1.5 * IQR
#         outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
        
#         if not outliers.empty:
#             outlier_columns[col] = len(outliers)

#     if outlier_columns:
#         print("Outliers detected in the following columns:")
#         for col, count in outlier_columns.items():
#             print(f"{col}: {count} outliers")
#     else:
#         print("No outliers detected.")

# Example usage
# df = pd.read_csv("your_dataset.csv")
# detect_outliers_iqr(df)

# %%
df.head()
# Out:
#     Age  Gender  Blood Pressure  Cholesterol Level Exercise Habits Smoking  \
# 0  56.0    Male           153.0              155.0            High     Yes
# 1  69.0  Female           146.0              286.0            High      No
# 2  46.0    Male           126.0              216.0             Low      No
# 3  32.0  Female           122.0              293.0            High     Yes
# 4  60.0    Male           166.0              242.0             Low     Yes
#
#   Family Heart Disease Diabetes        BMI High Blood Pressure  ...  \
# 0                  Yes       No  24.991591                 Yes  ...
# 1                  Yes      Yes  25.221799                  No  ...
# 2                   No       No  29.855447                  No  ...
# 3                  Yes       No  24.130477                 Yes  ...
# 4                  Yes      Yes  20.486289                 Yes  ...
#
#   High LDL Cholesterol Alcohol Consumption Stress Level Sleep Hours  \
# 0                   No                High       Medium    7.633228
# 1                   No              Medium         High    8.744034
# 2                  Yes                 Low          Low    4.440440
# 3                  Yes                 Low         High    5.249405
# 4                   No                 Low         High    7.030971
#
#    Sugar Consumption Triglyceride Level  Fasting Blood Sugar  CRP Level  \
# 0             Medium              342.0                120.0  12.969246
# 1             Medium              133.0                157.0   9.355389
# 2                Low              393.0                 92.0  12.709873
# 3               High              293.0                 94.0  12.509046
# 4               High              263.0                154.0  10.381259
#
#    Homocysteine Level  Heart Disease Status
# 0           12.387250                    No
# 1           19.298875                    No
# 2           11.230926                    No
# 3            5.961958                    No
# 4            8.153887                    No
#
# [5 rows x 21 columns]

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Univariate Plots numerical variables

# %%
num_cols = df.select_dtypes(include=['float64', 'int64']).columns

for col in num_cols:
    plt.figure(figsize=(6, 4))
    sns.histplot(df[col], kde=True)
    plt.title(f'Distribution of {col}')
    plt.show()

# %% [markdown]
# ## Univariate Plots categorical variables

# %%
cat_cols = df.select_dtypes(include='object').columns

for col in cat_cols:
    plt.figure(figsize=(6, 4))
    sns.countplot(x=col, data=df)
    plt.title(f'Countplot of {col}')
    plt.xticks(rotation=45)
    plt.show()

# %% [markdown]
# ## Bivariate Plots with Target (Heart Disease Status)

# %%
target = 'Heart Disease Status'

# Numerical vs Target
for col in num_cols:
    plt.figure(figsize=(6, 4))
    sns.boxplot(x=target, y=col, data=df)
    plt.title(f'{col} vs {target}')
    plt.show()

# %% [markdown]
# ## Bivariate Plots with Target (Heart Disease Status)

# %%
# Categorical vs Target
for col in cat_cols:
    plt.figure(figsize=(6, 4))
    sns.countplot(x=col, hue=target, data=df)
    plt.title(f'{col} by {target}')
    plt.xticks(rotation=45)
    plt.show()

# %% [markdown]
# ## Correlation Heatmap

# %%
plt.figure(figsize=(12, 10))
corr = df[num_cols].corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ## Outlier Detection (Boxplots)

# %%
for col in num_cols:
    plt.figure(figsize=(6, 4))
    sns.boxplot(x=df[col])
    plt.title(f'Boxplot of {col}')
    plt.show()

# %%
df.shape
# Out:
# (9803, 21)
