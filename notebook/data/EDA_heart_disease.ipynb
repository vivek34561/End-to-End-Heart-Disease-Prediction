# %%
# %pwd
# Out:
# 'c:\\Users\\vivek gupta\\Desktop\\Heart_disease_prediction\\notebook\\data'

# %%
import os
import sys
import pandas as pd

# %%
df = pd.read_csv('heart_disease.csv')

# %%
import pandas as pd
import numpy as np

# %%
df.head()
# Out:
#     Age  Gender  Blood Pressure  Cholesterol Level Exercise Habits Smoking  \
# 0  56.0    Male           153.0              155.0            High     Yes
# 1  69.0  Female           146.0              286.0            High      No
# 2  46.0    Male           126.0              216.0             Low      No
# 3  32.0  Female           122.0              293.0            High     Yes
# 4  60.0    Male           166.0              242.0             Low     Yes
#
#   Family Heart Disease Diabetes        BMI High Blood Pressure  ...  \
# 0                  Yes       No  24.991591                 Yes  ...
# 1                  Yes      Yes  25.221799                  No  ...
# 2                   No       No  29.855447                  No  ...
# 3                  Yes       No  24.130477                 Yes  ...
# 4                  Yes      Yes  20.486289                 Yes  ...
#
#   High LDL Cholesterol Alcohol Consumption Stress Level Sleep Hours  \
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Blood Pressure', 'Cholesterol Level',
#        'Exercise Habits', 'Smoking', 'Family Heart Disease', 'Diabetes', 'BMI',
#        'High Blood Pressure', 'Low HDL Cholesterol', 'High LDL Cholesterol',
#        'Alcohol Consumption', 'Stress Level', 'Sleep Hours',
#        'Sugar Consumption', 'Triglyceride Level', 'Fasting Blood Sugar',
#        'CRP Level', 'Homocysteine Level', 'Heart Disease Status'],
#       dtype='object')

# %%
df.shape
# Out:
# (10000, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Age                   9971 non-null   float64
#  1   Gender                9981 non-null   object
#  2   Blood Pressure        9981 non-null   float64
#  3   Cholesterol Level     9970 non-null   float64
#  4   Exercise Habits       9975 non-null   object
#  5   Smoking               9975 non-null   object
#  6   Family Heart Disease  9979 non-null   object
#  7   Diabetes              9970 non-null   object
#  8   BMI                   9978 non-null   float64
#  9   High Blood Pressure   9974 non-null   object
#  10  Low HDL Cholesterol   9975 non-null   object
#  11  High LDL Cholesterol  9974 non-null   object
#  12  Alcohol Consumption   7414 non-null   object
#  13  Stress Level          9978 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Age                       29
# Gender                    19
# Blood Pressure            19
# Cholesterol Level         30
# Exercise Habits           25
# Smoking                   25
# Family Heart Disease      21
# Diabetes                  30
# BMI                       22
# High Blood Pressure       26
# Low HDL Cholesterol       25
# High LDL Cholesterol      26
# Alcohol Consumption     2586
# Stress Level              22
# Sleep Hours               25
# Sugar Consumption         30
# Triglyceride Level        26
# Fasting Blood Sugar       22
# CRP Level                 26
# Homocysteine Level        20
# Heart Disease Status       0
# dtype: int64

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female', nan], dtype=object)

# %%
df[df['Gender'].isnull()]
# Out:
#        Age Gender  Blood Pressure  Cholesterol Level Exercise Habits Smoking  \
# 424   50.0    NaN           147.0              264.0             Low     Yes
# 1550  43.0    NaN           152.0              187.0             Low      No
# 1770  24.0    NaN           150.0              289.0          Medium      No
# 1956  54.0    NaN           176.0              171.0             Low     Yes
# 2056  62.0    NaN           134.0              195.0          Medium     Yes
# 2403  20.0    NaN           135.0              155.0            High      No
# 2917  18.0    NaN           170.0              204.0            High     Yes
# 3221  37.0    NaN           135.0              207.0          Medium     Yes
# 3249  33.0    NaN           142.0              240.0             Low     Yes
# 3837  47.0    NaN           157.0              216.0          Medium     Yes
# 3956  61.0    NaN           158.0              180.0             Low     Yes
# ...

# %%
df['Exercise Habits'].unique()
# Out:
# array(['High', 'Low', 'Medium', nan], dtype=object)

# %% [markdown]
# ### Target
# 1-> handle null values
#
# remove null rows Gender , Exercise Habits , Smoking , Family Heart Disease , Diabetes
# High Blood Pressure   ,
# Low HDL Cholesterol  ,
# High LDL Cholesterol  ,
# Stress Level      ,
# Sugar Consumption   ,
# Fasting Blood Sugar  ,

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Blood Pressure', 'Cholesterol Level',
#        'Exercise Habits', 'Smoking', 'Family Heart Disease', 'Diabetes', 'BMI',
#        'High Blood Pressure', 'Low HDL Cholesterol', 'High LDL Cholesterol',
#        'Alcohol Consumption', 'Stress Level', 'Sleep Hours',
#        'Sugar Consumption', 'Triglyceride Level', 'Fasting Blood Sugar',
#        'CRP Level', 'Homocysteine Level', 'Heart Disease Status'],
#       dtype='object')

# %%
df['Heart Disease Status'].value_counts()
# Out:
# Heart Disease Status
# No     8000
# Yes    2000
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#                Age  Blood Pressure  Cholesterol Level          BMI  \
# count  9971.000000     9981.000000        9970.000000  9978.000000
# mean     49.296259      149.757740         225.425577    29.077269
# std      18.193970       17.572969          43.575809     6.307098
# min      18.000000      120.000000         150.000000    18.002837
# 25%      34.000000      134.000000         187.000000    23.658075
# 50%      49.000000      150.000000         226.000000    29.079492
# 75%      65.000000      165.000000         263.000000    34.520015
# max      80.000000      180.000000         300.000000    39.996954
#
#        Sleep Hours  Triglyceride Level  Fasting Blood Sugar    CRP Level  \
# count  9975.000000         9974.000000          9978.000000  9974.000000
# mean      6.991329          250.734409           120.142213     7.472201
# std       1.753195           87.067226            23.584011     4.340248
# ...

# %%
df.head()
# Out:
#     Age  Gender  Blood Pressure  Cholesterol Level Exercise Habits Smoking  \
# 0  56.0    Male           153.0              155.0            High     Yes
# 1  69.0  Female           146.0              286.0            High      No
# 2  46.0    Male           126.0              216.0             Low      No
# 3  32.0  Female           122.0              293.0            High     Yes
# 4  60.0    Male           166.0              242.0             Low     Yes
#
#   Family Heart Disease Diabetes        BMI High Blood Pressure  ...  \
# 0                  Yes       No  24.991591                 Yes  ...
# 1                  Yes      Yes  25.221799                  No  ...
# 2                   No       No  29.855447                  No  ...
# 3                  Yes       No  24.130477                 Yes  ...
# 4                  Yes      Yes  20.486289                 Yes  ...
#
#   High LDL Cholesterol Alcohol Consumption Stress Level Sleep Hours  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Age                   9971 non-null   float64
#  1   Gender                9981 non-null   object
#  2   Blood Pressure        9981 non-null   float64
#  3   Cholesterol Level     9970 non-null   float64
#  4   Exercise Habits       9975 non-null   object
#  5   Smoking               9975 non-null   object
#  6   Family Heart Disease  9979 non-null   object
#  7   Diabetes              9970 non-null   object
#  8   BMI                   9978 non-null   float64
#  9   High Blood Pressure   9974 non-null   object
#  10  Low HDL Cholesterol   9975 non-null   object
#  11  High LDL Cholesterol  9974 non-null   object
#  12  Alcohol Consumption   7414 non-null   object
#  13  Stress Level          9978 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Age                       29
# Gender                    19
# Blood Pressure            19
# Cholesterol Level         30
# Exercise Habits           25
# Smoking                   25
# Family Heart Disease      21
# Diabetes                  30
# BMI                       22
# High Blood Pressure       26
# Low HDL Cholesterol       25
# High LDL Cholesterol      26
# Alcohol Consumption     2586
# Stress Level              22
# Sleep Hours               25
# Sugar Consumption         30
# Triglyceride Level        26
# Fasting Blood Sugar       22
# CRP Level                 26
# Homocysteine Level        20
# Heart Disease Status       0
# dtype: int64

# %%
df.shape
# Out:
# (10000, 21)

# %%
# Separate categorical and numerical columns
categorical_cols = df.select_dtypes(include=['object', 'category']).columns.tolist()
numerical_cols = df.select_dtypes(include=['number']).columns.tolist()

print("Categorical Columns:", categorical_cols)
print("Numerical Columns:", numerical_cols)
# Out:
# Categorical Columns: ['Gender', 'Exercise Habits', 'Smoking', 'Family Heart Disease', 'Diabetes', 'High Blood Pressure', 'Low HDL Cholesterol', 'High LDL Cholesterol', 'Alcohol Consumption', 'Stress Level', 'Sugar Consumption', 'Heart Disease Status']
# Numerical Columns: ['Age', 'Blood Pressure', 'Cholesterol Level', 'BMI', 'Sleep Hours', 'Triglyceride Level', 'Fasting Blood Sugar', 'CRP Level', 'Homocysteine Level']

# %%
import numpy as np
import pandas as pd

# Set random seed for reproducibility
np.random.seed(42)

# Example: simulate your dataset (use your actual DataFrame instead)
# df = pd.read_csv('your_dataset.csv')

# Define categories
categories = ['High', 'Medium', 'Low']

# Identify missing values in 'Alcohol Consumption'
mask = df['Alcohol Consumption'].isna()

# Randomly assign values with equal probability
df.loc[mask, 'Alcohol Consumption'] = np.random.choice(categories, size=mask.sum(), replace=True)

# %%
# Handling missing values 
# gender -> mode
# exercise habits -> mode
# smoking -> mode
# Family Heart Disease -> mode
# diabeties -> mode
# High Blood Pressure -> mode
# Low HDL Cholesterol -> mode
# stress Level -> mode
# sugar Consumption -> mode
# fasting Blood Sugar -> mean
# Drop columns with too many missing values
threshold = 0.4  # 40%
missing_percent = df.isnull().sum() / len(df)
df = df.drop(columns=missing_percent[missing_percent > threshold].index)

# Fill categorical with mode
cat_cols = df.select_dtypes(include=['object', 'category']).columns
for col in cat_cols:
    df[col] = df[col].fillna(df[col].mode()[0])

# Fill numerical with median
num_cols = df.select_dtypes(include=['number']).columns
for col in num_cols:
    df[col] = df[col].fillna(df[col].median())

# %%
df.isnull().sum()
# Out:
# Age                     0
# Gender                  0
# Blood Pressure          0
# Cholesterol Level       0
# Exercise Habits         0
# Smoking                 0
# Family Heart Disease    0
# Diabetes                0
# BMI                     0
# High Blood Pressure     0
# Low HDL Cholesterol     0
# High LDL Cholesterol    0
# Alcohol Consumption     0
# Stress Level            0
# Sleep Hours             0
# Sugar Consumption       0
# Triglyceride Level      0
# Fasting Blood Sugar     0
# CRP Level               0
# Homocysteine Level      0
# Heart Disease Status    0
# dtype: int64

# %%
df.head()
# Out:
#     Age  Gender  Blood Pressure  Cholesterol Level Exercise Habits Smoking  \
# 0  56.0    Male           153.0              155.0            High     Yes
# 1  69.0  Female           146.0              286.0            High      No
# 2  46.0    Male           126.0              216.0             Low      No
# 3  32.0  Female           122.0              293.0            High     Yes
# 4  60.0    Male           166.0              242.0             Low     Yes
#
#   Family Heart Disease Diabetes        BMI High Blood Pressure  ...  \
# 0                  Yes       No  24.991591                 Yes  ...
# 1                  Yes      Yes  25.221799                  No  ...
# 2                   No       No  29.855447                  No  ...
# 3                  Yes       No  24.130477                 Yes  ...
# 4                  Yes      Yes  20.486289                 Yes  ...
#
#   High LDL Cholesterol Alcohol Consumption Stress Level Sleep Hours  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Age                   10000 non-null  float64
#  1   Gender                10000 non-null  object
#  2   Blood Pressure        10000 non-null  float64
#  3   Cholesterol Level     10000 non-null  float64
#  4   Exercise Habits       10000 non-null  object
#  5   Smoking               10000 non-null  object
#  6   Family Heart Disease  10000 non-null  object
#  7   Diabetes              10000 non-null  object
#  8   BMI                   10000 non-null  float64
#  9   High Blood Pressure   10000 non-null  object
#  10  Low HDL Cholesterol   10000 non-null  object
#  11  High LDL Cholesterol  10000 non-null  object
#  12  Alcohol Consumption   10000 non-null  object
#  13  Stress Level          10000 non-null  object
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Blood Pressure', 'Cholesterol Level',
#        'Exercise Habits', 'Smoking', 'Family Heart Disease', 'Diabetes', 'BMI',
#        'High Blood Pressure', 'Low HDL Cholesterol', 'High LDL Cholesterol',
#        'Alcohol Consumption', 'Stress Level', 'Sleep Hours',
#        'Sugar Consumption', 'Triglyceride Level', 'Fasting Blood Sugar',
#        'CRP Level', 'Homocysteine Level', 'Heart Disease Status'],
#       dtype='object')

# %%
df.head()
# Out:
#     Age  Gender  Blood Pressure  Cholesterol Level Exercise Habits Smoking  \
# 0  56.0    Male           153.0              155.0            High     Yes
# 1  69.0  Female           146.0              286.0            High      No
# 2  46.0    Male           126.0              216.0             Low      No
# 3  32.0  Female           122.0              293.0            High     Yes
# 4  60.0    Male           166.0              242.0             Low     Yes
#
#   Family Heart Disease Diabetes        BMI High Blood Pressure  ...  \
# 0                  Yes       No  24.991591                 Yes  ...
# 1                  Yes      Yes  25.221799                  No  ...
# 2                   No       No  29.855447                  No  ...
# 3                  Yes       No  24.130477                 Yes  ...
# 4                  Yes      Yes  20.486289                 Yes  ...
#
#   High LDL Cholesterol Alcohol Consumption Stress Level Sleep Hours  \
# ...

# %%
# import pandas as pd

# def detect_outliers_iqr(df):
#     outlier_columns = {}
#     for col in df.select_dtypes(include=['float64', 'int64']).columns:
#         Q1 = df[col].quantile(0.25)
#         Q3 = df[col].quantile(0.75)
#         IQR = Q3 - Q1
#         lower_bound = Q1 - 1.5 * IQR
#         upper_bound = Q3 + 1.5 * IQR
#         outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
        
#         if not outliers.empty:
#             outlier_columns[col] = len(outliers)

#     if outlier_columns:
#         print("Outliers detected in the following columns:")
#         for col, count in outlier_columns.items():
#             print(f"{col}: {count} outliers")
#     else:
#         print("No outliers detected.")

# Example usage
# df = pd.read_csv("your_dataset.csv")
# detect_outliers_iqr(df)

# %%
df.head()
# Out:
#     Age  Gender  Blood Pressure  Cholesterol Level Exercise Habits Smoking  \
# 0  56.0    Male           153.0              155.0            High     Yes
# 1  69.0  Female           146.0              286.0            High      No
# 2  46.0    Male           126.0              216.0             Low      No
# 3  32.0  Female           122.0              293.0            High     Yes
# 4  60.0    Male           166.0              242.0             Low     Yes
#
#   Family Heart Disease Diabetes        BMI High Blood Pressure  ...  \
# 0                  Yes       No  24.991591                 Yes  ...
# 1                  Yes      Yes  25.221799                  No  ...
# 2                   No       No  29.855447                  No  ...
# 3                  Yes       No  24.130477                 Yes  ...
# 4                  Yes      Yes  20.486289                 Yes  ...
#
#   High LDL Cholesterol Alcohol Consumption Stress Level Sleep Hours  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Univariate Plots numerical variables

# %%
num_cols = df.select_dtypes(include=['float64', 'int64']).columns

for col in num_cols:
    plt.figure(figsize=(6, 4))
    sns.histplot(df[col], kde=True)
    plt.title(f'Distribution of {col}')
    plt.show()

# %% [markdown]
# ## Univariate Plots categorical variables

# %%
cat_cols = df.select_dtypes(include='object').columns

for col in cat_cols:
    plt.figure(figsize=(6, 4))
    sns.countplot(x=col, data=df)
    plt.title(f'Countplot of {col}')
    plt.xticks(rotation=45)
    plt.show()

# %% [markdown]
# ## Bivariate Plots with Target (Heart Disease Status)

# %%
target = 'Heart Disease Status'

# Numerical vs Target
for col in num_cols:
    plt.figure(figsize=(6, 4))
    sns.boxplot(x=target, y=col, data=df)
    plt.title(f'{col} vs {target}')
    plt.show()

# %% [markdown]
# ## Bivariate Plots with Target (Heart Disease Status)

# %%
# Categorical vs Target
for col in cat_cols:
    plt.figure(figsize=(6, 4))
    sns.countplot(x=col, hue=target, data=df)
    plt.title(f'{col} by {target}')
    plt.xticks(rotation=45)
    plt.show()

# %% [markdown]
# ## Correlation Heatmap

# %%
plt.figure(figsize=(12, 10))
corr = df[num_cols].corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ## Outlier Detection (Boxplots)

# %%
for col in num_cols:
    plt.figure(figsize=(6, 4))
    sns.boxplot(x=df[col])
    plt.title(f'Boxplot of {col}')
    plt.show()

# %%
df.shape
# Out:
# (10000, 21)

# %%
# save the df to csv

df.to_csv(r'C:\Users\vivek gupta\Desktop\Heart_disease_prediction\notebook\data\cleaned_data.csv', index=False)

print('Data saved successfully.')

# import pandas as pd
# Out:
# Data saved successfully.

# %%
import os
import pandas as pd

# Best practice using os.path.join (platform-independent)
new_df = pd.read_csv(r'C:\Users\vivek gupta\Desktop\Heart_disease_prediction\notebook\data\cleaned_data.csv')

# %%
new_df.isnull().sum()
# Out:
# Age                     0
# Gender                  0
# Blood Pressure          0
# Cholesterol Level       0
# Exercise Habits         0
# Smoking                 0
# Family Heart Disease    0
# Diabetes                0
# BMI                     0
# High Blood Pressure     0
# Low HDL Cholesterol     0
# High LDL Cholesterol    0
# Alcohol Consumption     0
# Stress Level            0
# Sleep Hours             0
# Sugar Consumption       0
# Triglyceride Level      0
# Fasting Blood Sugar     0
# CRP Level               0
# Homocysteine Level      0
# Heart Disease Status    0
# dtype: int64

# %%
new_df = pd.read_csv('cleaned_data.csv')

# %%
new_df['Heart Disease Status'].value_counts()
# Out:
# Heart Disease Status
# No     8000
# Yes    2000
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# Age                     0
# Gender                  0
# Blood Pressure          0
# Cholesterol Level       0
# Exercise Habits         0
# Smoking                 0
# Family Heart Disease    0
# Diabetes                0
# BMI                     0
# High Blood Pressure     0
# Low HDL Cholesterol     0
# High LDL Cholesterol    0
# Alcohol Consumption     0
# Stress Level            0
# Sleep Hours             0
# Sugar Consumption       0
# Triglyceride Level      0
# Fasting Blood Sugar     0
# CRP Level               0
# Homocysteine Level      0
# Heart Disease Status    0
# dtype: int64

# %%
new_df.isnull().sum()
# Out:
# Age                     0
# Gender                  0
# Blood Pressure          0
# Cholesterol Level       0
# Exercise Habits         0
# Smoking                 0
# Family Heart Disease    0
# Diabetes                0
# BMI                     0
# High Blood Pressure     0
# Low HDL Cholesterol     0
# High LDL Cholesterol    0
# Alcohol Consumption     0
# Stress Level            0
# Sleep Hours             0
# Sugar Consumption       0
# Triglyceride Level      0
# Fasting Blood Sugar     0
# CRP Level               0
# Homocysteine Level      0
# Heart Disease Status    0
# dtype: int64
